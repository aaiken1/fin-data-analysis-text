# %% [markdown]
# # Databento
#
# [Databento](https://databento.com/) is a modern market data platform designed for quantitative research and algorithmic trading. It provides high-quality historical and real-time data for:
#
# - **Equities** - US stocks and ETFs
# - **Futures** - CME, ICE, and other exchanges
# - **Options** - US equity options
#
# ## Why Databento?
#
# - **Clean, normalized data** - Consistent format across exchanges
# - **Flexible pricing** - Pay only for what you use
# - **Python-first** - Excellent Python SDK
# - **Academic discounts** - Available for students and researchers
#
# ## Getting Started
#
# 1. Create an account at [databento.com](https://databento.com/)
# 2. Get your API key from the dashboard
# 3. Install the Python client:
#
# ```bash
# pip install databento
# ```

# %% [markdown]
# ## Set-up
#
# ```python
# import databento as db
# import os
# from dotenv import load_dotenv
#
# load_dotenv()
# DATABENTO_API_KEY = os.getenv('DATABENTO_API_KEY')
#
# # Initialize the client
# client = db.Historical(key=DATABENTO_API_KEY)
# ```

# %% [markdown]
# ## Example: Historical Stock Data
#
# ```python
# # Download daily OHLCV data for AAPL
# data = client.timeseries.get_range(
#     dataset="XNAS.ITCH",  # NASDAQ
#     symbols=["AAPL"],
#     schema="ohlcv-1d",
#     start="2024-01-01",
#     end="2024-06-30"
# )
#
# # Convert to DataFrame
# df = data.to_df()
# df.head()
# ```

# %% [markdown]
# ## Available Datasets
#
# | Dataset | Description |
# |---------|-------------|
# | `XNAS.ITCH` | NASDAQ TotalView-ITCH |
# | `XNYS.PILLAR` | NYSE Integrated Feed |
# | `GLBX.MDP3` | CME Globex futures |
# | `OPRA.PILLAR` | US equity options |
#
# See the [Databento documentation](https://databento.com/docs) for complete details.

# %% [markdown]
# ## Resources
#
# - [Databento Documentation](https://databento.com/docs)
# - [Python Client Reference](https://databento.com/docs/api-reference-historical/client)
# - [Pricing](https://databento.com/pricing)
#
# ```{note}
# This section will be expanded with working examples. Check back for updates!
# ```
